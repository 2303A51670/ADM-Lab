# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51670/ADM-Lab/blob/main/University_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/university_student.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     100 non-null    int64
#  1   Gender         100 non-null    object
#  2   Date of Birth  100 non-null    object
#  3   Study Time     100 non-null    int64
#  4   Grade          100 non-null    object
#  5   School Type    100 non-null    object
#  6   Absences       100 non-null    int64
#  7   Math Score     100 non-null    int64
#  8   Reading Score  100 non-null    int64
#  9   Writing Score  100 non-null    int64
# dtypes: int64(6), object(4)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        Student ID  Study Time    Absences  Math Score  Reading Score  \
# count  100.000000  100.000000  100.000000  100.000000     100.000000
# mean    50.500000    9.810000    2.500000   76.030000      74.370000
# std     29.011492    3.298898    1.672716   13.481341      14.457639
# min      1.000000    5.000000    0.000000   53.000000      50.000000
# 25%     25.750000    7.000000    1.000000   64.500000      61.750000
# 50%     50.500000   10.000000    3.000000   74.500000      75.500000
# 75%     75.250000   13.000000    4.000000   86.250000      86.250000
# max    100.000000   15.000000    5.000000  100.000000      99.000000
#
#        Writing Score
# count     100.000000
# mean       74.850000
# std        15.763002
# min        50.000000
# 25%        61.750000
# 50%        75.500000
# 75%        87.000000
# max       100.000000

# %%
df.head()
# Out:
#    Student ID  Gender Date of Birth  Study Time Grade School Type  Absences  \
# 0           1    Male    1996-12-03          11     D      Public         2
# 1           2  Female    2001-09-15           5     D     Private         0
# 2           3    Male    2002-08-09           8     A     Private         2
# 3           4    Male    1999-04-29           8     A     Private         3
# 4           5    Male    1995-06-11           9     B     Private         1
#
#    Math Score  Reading Score  Writing Score
# 0          72             91             69
# 1          66             58             62
# 2          75             99             77
# 3          57             76             97
# 4          78             51             78

# %%
df.tail()
# Out:
#     Student ID  Gender Date of Birth  Study Time Grade School Type  Absences  \
# 95          96  Female    2004-12-04           8     C      Public         1
# 96          97  Female    2003-01-18           7     B     Private         4
# 97          98  Female    1999-01-24          14     A     Private         2
# 98          99  Female    2005-04-20           7     B     Private         1
# 99         100    Male    2004-12-25           7     B     Private         2
#
#     Math Score  Reading Score  Writing Score
# 95          87             85             88
# 96          56             76             87
# 97          95             66             83
# 98          62             58             87
# 99          89             82             99

# %%
print("First 10 rows of the dataset:")
print(df.head(10))
# Out:
# First 10 rows of the dataset:
#    Student ID  Gender Date of Birth  Study Time Grade School Type  Absences  \
# 0           1    Male    1996-12-03          11     D      Public         2
# 1           2  Female    2001-09-15           5     D     Private         0
# 2           3    Male    2002-08-09           8     A     Private         2
# 3           4    Male    1999-04-29           8     A     Private         3
# 4           5    Male    1995-06-11           9     B     Private         1
# 5           6  Female    1995-07-21          11     A     Private         1
# 6           7    Male    2000-06-04          11     C      Public         4
# 7           8    Male    1997-09-22          15     D     Private         1
# 8           9    Male    2001-05-06           8     A      Public         4
# 9          10  Female    2005-10-09          11     A     Private         5
#
#    Math Score  Reading Score  Writing Score
# 0          72             91             69
# 1          66             58             62
# 2          75             99             77
# 3          57             76             97
# 4          78             51             78
# 5          75             54             62
# 6          59             78             95
# 7          75             86             84
# 8          83             87             55
# 9         100             68             67

# %%
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# Student ID       0
# Gender           0
# Date of Birth    0
# Study Time       0
# Grade            0
# School Type      0
# Absences         0
# Math Score       0
# Reading Score    0
# Writing Score    0
# dtype: int64

# %%
df_encoded = pd.get_dummies(df, columns=['Gender', 'School Type'], drop_first=True)

# %%
print("\nDataset after one-hot encoding:")
print(df_encoded.head())
# Out:
# Dataset after one-hot encoding:
#    Student ID Date of Birth  Study Time Grade  Absences  Math Score  \
# 0           1    1996-12-03          11     D         2          72
# 1           2    2001-09-15           5     D         0          66
# 2           3    2002-08-09           8     A         2          75
# 3           4    1999-04-29           8     A         3          57
# 4           5    1995-06-11           9     B         1          78
#
#    Reading Score  Writing Score  Gender_Male  School Type_Public
# 0             91             69         True                True
# 1             58             62        False               False
# 2             99             77         True               False
# 3             76             97         True               False
# 4             51             78         True               False

# %%
match_stats = df['Math Score'].agg(['mean', 'median', 'std'])
print('\nMath Score Statistics:')
print(match_stats)
# Out:
# Math Score Statistics:
# mean      76.030000
# median    74.500000
# std       13.481341
# Name: Math Score, dtype: float64

# %%
school_counts = df['School Type'].value_counts()
print("\nTotal number of students per school Type:")
print(school_counts)
# Out:
# Total number of students per school Type:
# School Type
# Private    59
# Public     41
# Name: count, dtype: int64
